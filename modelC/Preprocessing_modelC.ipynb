# %% [markdown]
# <h1>10. Add reforecast wind data

# %%
import numpy as np
import pandas as pd
import xarray as xr
import json
import os
from scipy.interpolate import interp2d
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Define lead times
lead_times = list(range(0, 145, 3))

# Load wind power plant (WPP) data
with open(r"E:\MA_data\WPPs+production\WPPs+production_new_complete.json", "r", encoding="utf-8") as f:
    wpps = json.load(f)

lead_time_dicts = {str(lt): {} for lt in lead_times}  # Initialize empty structure

# Forecast file directory
forecast_dir = r"E:\MA_data\reforecast data ECMWF raw"

# Process each GRIB file (one per month-year)
grib_files = sorted([f for f in os.listdir(forecast_dir) if f.endswith(".grib")])

for grib_file in grib_files:

    # Output JSON file path for this month-year
    output_json_file = os.path.join(r"E:\MA_data\WPPs+production+reforecast_monthwise", f"{grib_file.replace('.grib', '_wind.json')}")

    # Check if this month's data has already been processed
    if os.path.exists(output_json_file):
        print(f"Skipping {grib_file} (already processed)")
        continue  # Skip to the next GRIB file

    print(f"Processing {grib_file}")
        
    _, year, month = grib_file.replace(".grib", "").split("_")
    year, month = int(year), int(month)
    grib_path = os.path.join(forecast_dir, grib_file)

    # Load wind speed forecast data
    try:
        ds = xr.open_dataset(grib_path, engine="cfgrib", chunks={"time": 100})
    except Exception as e:
        print(f"Error reading {grib_file}: {e} --> skipping")
        continue

    # Extract forecast timestamps and wind components
    times = pd.to_datetime(ds["valid_time"].values)
    latitudes = ds["latitude"].values
    longitudes = ds["longitude"].values
    u = ds["u100"].values
    v = ds["v100"].values

    # Process each WPP
    for i, wpp in enumerate(wpps):
        
        json_id = wpp["JSON-ID"]
        wpp_id = wpp["ID_The-Wind-Power"]
        unique_key = f"{json_id}_{wpp_id}"  # Unique identifier of a wpp

        lon = wpp["Longitude"]
        lat = wpp["Latitude"]

        # Convert production timestamps to pandas datetime format
        date_range = pd.to_datetime([entry[0] for entry in wpp["Production"]])
        production_values = [entry[1] for entry in wpp["Production"]]

        # Filter production data for this month-year
        month_mask = (date_range.year == year) & (date_range.month == month)
        production_df = pd.DataFrame({"date": date_range[month_mask], "production": np.array(production_values)[month_mask]})

        if production_df["production"].empty:
            print(f"WPP {i+1}/{len(wpps)} has no production data for {year}/{month}, skipping...")
            continue

        print(f"WPP {i+1}/{len(wpps)} for year {year}/{month}")

        forecast_data = []

        for _, row in production_df.iterrows():
            timestep = row["date"]
            production = row["production"]
            for j in range(len(times)):
                forecast_times = times[j]
                if timestep in forecast_times:
                    forecast_times = pd.DatetimeIndex(forecast_times) # convert from DatetimeArray to DatetimeIndex, because only this one has .get_loc()
                    time_index = forecast_times.get_loc(timestep)
                    lead_time = lead_times[time_index]

                    forecast_u = u[j]
                    forecast_v = v[j]

                    wind_speeds = np.sqrt(forecast_u[time_index]**2 + forecast_v[time_index]**2)
                    spatial_interpolator = interp2d(longitudes, latitudes, wind_speeds, kind='linear')
                    wind_speed_value = spatial_interpolator(lon, lat)[0]
                    wind_speed_value = round(wind_speed_value, 2)

                    forecast_data.append([lead_time, timestep, production, wind_speed_value])

        forecast_df = pd.DataFrame(forecast_data, columns=["lead_time", "forecast_time", "production", "wind_speed"])

        # Store data in structured dictionary grouped by lead time
        for lead_time in lead_times:
            lead_time_str = str(lead_time)  # Ensure keys are strings for JSON compatibility

            # Select data points corresponding to this lead time
            lead_time_mask = forecast_df["lead_time"] == lead_time
            lead_time_data = forecast_df[lead_time_mask]

            if lead_time_data.empty:
                continue  # Skip if no data for this lead time

            # Initialize new WPP entry
            lead_time_dicts[lead_time_str][unique_key] = {
                "Name": wpp["Name"],
                "Names_UK_Plants": wpp["Names_UK_Plants"],
                "Code": wpp["Code"],
                "Type": wpp["Type"],
                "Capacity": wpp["Capacity"],
                "Continent": wpp["Continent"],
                "ISO_code": wpp["ISO_code"],
                "Country": wpp["Country"],
                "State_code": wpp["State_code"],
                "Area": wpp["Area"],
                "City": wpp["City"],
                "Name_TWP": wpp["Name_TWP"],
                "Second_name": wpp["Second_name"],
                "Latitude": wpp["Latitude"],
                "Longitude": wpp["Longitude"],
                "Altitude_Depth": wpp["Altitude_Depth"],
                "Location_accuracy": wpp["Location_accuracy"],
                "Shore_distance_km": wpp["Shore_distance_km"],
                "Manufacturer": wpp["Manufacturer"],
                "Turbine": wpp["Turbine"],
                "Hub_height": wpp["Hub_height"],
                "Number_of_turbines": wpp["Number_of_turbines"],
                "Developer": wpp["Developer"],
                "Operator": wpp["Operator"],
                "Owner": wpp["Owner"],
                "Commissioning_date": wpp["Commissioning_date"],
                "Status": wpp["Status"],
                "Decommissioning_date": wpp["Decommissioning_date"],
                "Source_link": wpp["Source_link"],
                "Last_update": wpp["Last_update"],
                "Time Series": [[str(date), production, wind_speed] for _, date, production, wind_speed in lead_time_data[["lead_time", "forecast_time", "production", "wind_speed"]].values.tolist()]
            }

    # Save updated JSON
    with open(output_json_file, "w", encoding="utf-8") as f:
        json.dump(lead_time_dicts, f, indent=4)

    print(f"Updated JSON file saved: {output_json_file}")
# Out:
# Skipping europe_2015_01.grib (already processed)
# Skipping europe_2015_02.grib (already processed)
# Skipping europe_2015_03.grib (already processed)
# Skipping europe_2015_04.grib (already processed)
# Skipping europe_2015_05.grib (already processed)
# Skipping europe_2015_06.grib (already processed)
# Skipping europe_2015_07.grib (already processed)
# Skipping europe_2015_08.grib (already processed)
# Skipping europe_2015_09.grib (already processed)
# Skipping europe_2015_10.grib (already processed)
# Skipping europe_2015_11.grib (already processed)
# Skipping europe_2015_12.grib (already processed)
# Skipping europe_2016_01.grib (already processed)
# Skipping europe_2016_02.grib (already processed)
# Skipping europe_2016_03.grib (already processed)
# Skipping europe_2016_04.grib (already processed)
# Skipping europe_2016_05.grib (already processed)
# Skipping europe_2016_06.grib (already processed)
# Skipping europe_2016_07.grib (already processed)
# Skipping europe_2016_08.grib (already processed)
# Skipping europe_2016_09.grib (already processed)
# Skipping europe_2016_10.grib (already processed)
# Skipping europe_2016_11.grib (already processed)
# Skipping europe_2016_12.grib (already processed)
# Skipping europe_2017_01.grib (already processed)
# Skipping europe_2017_02.grib (already processed)
# Skipping europe_2017_03.grib (already processed)
# Skipping europe_2017_04.grib (already processed)
# Skipping europe_2017_05.grib (already processed)
# WPP 139/156 has no production data for 2018/1, skipping...
# WPP 140/156 has no production data for 2018/1, skipping...
# WPP 141/156 has no production data for 2018/1, skipping...
# WPP 142/156 has no production data for 2018/1, skipping...
# WPP 143/156 for year 2018/1
# WPP 144/156 has no production data for 2018/1, skipping...
# WPP 145/156 has no production data for 2018/1, skipping...
# WPP 146/156 for year 2018/1
# WPP 147/156 for year 2018/1
# WPP 148/156 has no production data for 2018/1, skipping...
# WPP 149/156 for year 2018/1
# WPP 150/156 for year 2018/1
# WPP 151/156 for year 2018/1
# WPP 152/156 for year 2018/1
# WPP 153/156 for year 2018/1
# WPP 154/156 for year 2018/1
# WPP 155/156 for year 2018/1
# WPP 156/156 for year 2018/1
# Updated JSON file saved: E:\MA_data\WPPs+production+reforecast\europe_2018_01_wind.json
# Processing europe_2018_02.grib
# WPP 1/156 has no production data for 2018/2, skipping...
# WPP 2/156 has no production data for 2018/2, skipping...
# WPP 3/156 has no production data for 2018/2, skipping...
# WPP 4/156 has no production data for 2018/2, skipping...
# WPP 5/156 has no production data for 2018/2, skipping...
# WPP 6/156 has no production data for 2018/2, skipping...
# WPP 7/156 for year 2018/2
# WPP 8/156 for year 2018/2
# WPP 9/156 for year 2018/2
# WPP 10/156 has no production data for 2018/2, skipping...
# WPP 11/156 for year 2018/2
# WPP 12/156 for year 2018/2
# WPP 13/156 has no production data for 2018/2, skipping...
# WPP 14/156 has no production data for 2018/2, skipping...
# WPP 15/156 has no production data for 2018/2, skipping...
# WPP 16/156 has no production data for 2018/2, skipping...
# WPP 17/156 for year 2018/2
# WPP 18/156 for year 2018/2
# WPP 19/156 for year 2018/2
# WPP 20/156 has no production data for 2018/2, skipping...
# WPP 21/156 has no production data for 2018/2, skipping...
# WPP 22/156 for year 2018/2
# WPP 23/156 for year 2018/2
# WPP 24/156 for year 2018/2
# WPP 25/156 for year 2018/2
# WPP 26/156 has no production data for 2018/2, skipping...
# WPP 27/156 for year 2018/2
# WPP 28/156 for year 2018/2
# WPP 29/156 has no production data for 2018/2, skipping...
# WPP 30/156 has no production data for 2018/2, skipping...
# WPP 31/156 for year 2018/2
# WPP 32/156 has no production data for 2018/2, skipping...
# WPP 33/156 has no production data for 2018/2, skipping...
# WPP 34/156 for year 2018/2
# WPP 35/156 has no production data for 2018/2, skipping...
# WPP 36/156 for year 2018/2
# WPP 37/156 for year 2018/2
# WPP 38/156 for year 2018/2
# WPP 39/156 has no production data for 2018/2, skipping...
# WPP 40/156 for year 2018/2
# WPP 41/156 has no production data for 2018/2, skipping...
# WPP 42/156 has no production data for 2018/2, skipping...
# WPP 43/156 has no production data for 2018/2, skipping...
# WPP 44/156 has no production data for 2018/2, skipping...
# WPP 45/156 has no production data for 2018/2, skipping...
# WPP 46/156 has no production data for 2018/2, skipping...
# WPP 47/156 has no production data for 2018/2, skipping...
# WPP 48/156 for year 2018/2
# WPP 49/156 has no production data for 2018/2, skipping...
# WPP 50/156 for year 2018/2
# WPP 51/156 has no production data for 2018/2, skipping...
# WPP 52/156 has no production data for 2018/2, skipping...
# WPP 53/156 has no production data for 2018/2, skipping...
# WPP 54/156 has no production data for 2018/2, skipping...
# WPP 55/156 has no production data for 2018/2, skipping...
# WPP 56/156 has no production data for 2018/2, skipping...
# WPP 57/156 has no production data for 2018/2, skipping...
# WPP 58/156 for year 2018/2
# WPP 59/156 has no production data for 2018/2, skipping...
# WPP 60/156 for year 2018/2
# WPP 61/156 for year 2018/2
# WPP 62/156 for year 2018/2
# WPP 63/156 for year 2018/2
# WPP 64/156 for year 2018/2
# WPP 65/156 for year 2018/2
# WPP 66/156 for year 2018/2
# WPP 67/156 for year 2018/2
# WPP 68/156 for year 2018/2
# WPP 69/156 for year 2018/2
# WPP 70/156 for year 2018/2
# WPP 71/156 for year 2018/2
# WPP 72/156 for year 2018/2
# WPP 73/156 for year 2018/2
# WPP 74/156 has no production data for 2018/2, skipping...
# WPP 75/156 has no production data for 2018/2, skipping...
# WPP 76/156 has no production data for 2018/2, skipping...
# WPP 77/156 has no production data for 2018/2, skipping...
# WPP 78/156 has no production data for 2018/2, skipping...
# WPP 79/156 has no production data for 2018/2, skipping...
# WPP 80/156 has no production data for 2018/2, skipping...
# WPP 81/156 has no production data for 2018/2, skipping...
# WPP 82/156 has no production data for 2018/2, skipping...
# WPP 83/156 for year 2018/2
# WPP 84/156 has no production data for 2018/2, skipping...
# WPP 85/156 for year 2018/2
# WPP 86/156 for year 2018/2
# WPP 87/156 has no production data for 2018/2, skipping...
# WPP 88/156 for year 2018/2
# WPP 89/156 for year 2018/2
# WPP 90/156 for year 2018/2
# WPP 91/156 has no production data for 2018/2, skipping...
# WPP 92/156 has no production data for 2018/2, skipping...
# WPP 93/156 has no production data for 2018/2, skipping...
# WPP 94/156 has no production data for 2018/2, skipping...
# WPP 95/156 for year 2018/2
# WPP 96/156 for year 2018/2
# WPP 97/156 has no production data for 2018/2, skipping...
# WPP 98/156 for year 2018/2
# WPP 99/156 for year 2018/2
# WPP 100/156 has no production data for 2018/2, skipping...
# WPP 101/156 for year 2018/2
# WPP 102/156 for year 2018/2
# WPP 103/156 has no production data for 2018/2, skipping...
# WPP 104/156 for year 2018/2
# WPP 105/156 for year 2018/2
# WPP 106/156 for year 2018/2
# WPP 107/156 for year 2018/2
# WPP 108/156 has no production data for 2018/2, skipping...
# WPP 109/156 has no production data for 2018/2, skipping...
# WPP 110/156 for year 2018/2
# WPP 111/156 has no production data for 2018/2, skipping...
# WPP 112/156 has no production data for 2018/2, skipping...
# WPP 113/156 has no production data for 2018/2, skipping...
# WPP 114/156 has no production data for 2018/2, skipping...
# WPP 115/156 has no production data for 2018/2, skipping...
# WPP 116/156 for year 2018/2
# WPP 117/156 for year 2018/2
# WPP 118/156 has no production data for 2018/2, skipping...
# WPP 119/156 has no production data for 2018/2, skipping...
# WPP 120/156 has no production data for 2018/2, skipping...
# WPP 121/156 has no production data for 2018/2, skipping...
# WPP 122/156 has no production data for 2018/2, skipping...
# WPP 123/156 has no production data for 2018/2, skipping...
# WPP 124/156 for year 2018/2
# WPP 125/156 for year 2018/2
# WPP 126/156 for year 2018/2
# WPP 127/156 has no production data for 2018/2, skipping...
# WPP 128/156 for year 2018/2
# WPP 129/156 for year 2018/2
# WPP 130/156 has no production data for 2018/2, skipping...
# WPP 131/156 has no production data for 2018/2, skipping...
# WPP 132/156 for year 2018/2
# WPP 133/156 has no production data for 2018/2, skipping...
# WPP 134/156 for year 2018/2
# WPP 135/156 for year 2018/2
# WPP 136/156 has no production data for 2018/2, skipping...
# WPP 137/156 has no production data for 2018/2, skipping...
# WPP 138/156 has no production data for 2018/2, skipping...
# WPP 139/156 has no production data for 2018/2, skipping...
# WPP 140/156 has no production data for 2018/2, skipping...
# WPP 141/156 has no production data for 2018/2, skipping...
# WPP 142/156 has no production data for 2018/2, skipping...
# WPP 143/156 for year 2018/2
# WPP 144/156 has no production data for 2018/2, skipping...
# WPP 145/156 has no production data for 2018/2, skipping...
# WPP 146/156 for year 2018/2
# WPP 147/156 for year 2018/2
# WPP 148/156 has no production data for 2018/2, skipping...
# WPP 149/156 for year 2018/2
# WPP 150/156 for year 2018/2
# WPP 151/156 for year 2018/2
# WPP 152/156 for year 2018/2
# WPP 153/156 for year 2018/2
# WPP 154/156 for year 2018/2
# WPP 155/156 for year 2018/2
# WPP 156/156 for year 2018/2
# Updated JSON file saved: E:\MA_data\WPPs+production+reforecast\europe_2018_02_wind.json
# Processing europe_2018_03.grib
# WPP 1/156 has no production data for 2018/3, skipping...
# WPP 2/156 has no production data for 2018/3, skipping...
# WPP 3/156 has no production data for 2018/3, skipping...
# WPP 4/156 has no production data for 2018/3, skipping...
# WPP 5/156 has no production data for 2018/3, skipping...
# WPP 6/156 has no production data for 2018/3, skipping...
# WPP 7/156 for year 2018/3
# WPP 8/156 for year 2018/3
# WPP 9/156 for year 2018/3
# WPP 10/156 has no production data for 2018/3, skipping...
# WPP 11/156 for year 2018/3
# WPP 12/156 for year 2018/3
# WPP 13/156 has no production data for 2018/3, skipping...
# WPP 14/156 has no production data for 2018/3, skipping...
# WPP 15/156 has no production data for 2018/3, skipping...
# WPP 16/156 has no production data for 2018/3, skipping...
# WPP 17/156 for year 2018/3
# WPP 18/156 for year 2018/3
# WPP 19/156 for year 2018/3
# WPP 20/156 has no production data for 2018/3, skipping...
# WPP 21/156 has no production data for 2018/3, skipping...
# WPP 22/156 for year 2018/3
# WPP 23/156 for year 2018/3
# WPP 24/156 for year 2018/3
# WPP 25/156 for year 2018/3
# WPP 26/156 has no production data for 2018/3, skipping...
# WPP 27/156 for year 2018/3
# WPP 28/156 for year 2018/3
# WPP 29/156 has no production data for 2018/3, skipping...
# WPP 30/156 has no production data for 2018/3, skipping...
# WPP 31/156 for year 2018/3
# WPP 32/156 has no production data for 2018/3, skipping...
# WPP 33/156 has no production data for 2018/3, skipping...
# WPP 34/156 for year 2018/3
# WPP 35/156 has no production data for 2018/3, skipping...
# WPP 36/156 for year 2018/3
# WPP 37/156 for year 2018/3
# WPP 38/156 for year 2018/3
# WPP 39/156 has no production data for 2018/3, skipping...
# WPP 40/156 for year 2018/3
# WPP 41/156 has no production data for 2018/3, skipping...
# WPP 42/156 has no production data for 2018/3, skipping...
# WPP 43/156 has no production data for 2018/3, skipping...
# WPP 44/156 has no production data for 2018/3, skipping...
# WPP 133/156 has no production data for 2018/9, skipping...
# WPP 134/156 for year 2018/9
# WPP 135/156 for year 2018/9
# WPP 136/156 has no production data for 2018/9, skipping...
# WPP 137/156 has no production data for 2018/9, skipping...
# WPP 138/156 for year 2018/9
# WPP 139/156 for year 2018/9
# WPP 140/156 for year 2018/9
# WPP 141/156 has no production data for 2018/9, skipping...
# WPP 142/156 has no production data for 2018/9, skipping...
# WPP 143/156 for year 2018/9
# WPP 144/156 has no production data for 2018/9, skipping...
# WPP 145/156 has no production data for 2018/9, skipping...
# WPP 146/156 for year 2018/9
# WPP 147/156 for year 2018/9
# WPP 148/156 has no production data for 2018/9, skipping...
# WPP 149/156 for year 2018/9
# WPP 150/156 for year 2018/9
# WPP 151/156 for year 2018/9
# WPP 152/156 for year 2018/9
# WPP 153/156 for year 2018/9

# %% [markdown]
# <h1>11. Merge all files into one per lead time

# %%
import os
import json
from collections import defaultdict

# Path to input JSON files
input_json_dir = r"E:\MA_data\WPPs+production+reforecast_monthwise"

# Dictionary to hold all data sorted by lead time
lead_time_dicts = defaultdict(lambda: defaultdict(dict))

# Load all JSON files
json_files = [f for f in os.listdir(input_json_dir) if f.endswith("_wind.json")]

for json_file in json_files:
    json_path = os.path.join(input_json_dir, json_file)
    print(f"Loading {json_file}")

    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Iterate over lead times in the loaded JSON
    for lead_time, wpp_data in data.items():
        for unique_key, wpp_entry in wpp_data.items():
            if unique_key in lead_time_dicts[lead_time]:
                # **Merge production data if the WPP already exists**
                lead_time_dicts[lead_time][unique_key]["Time Series"].extend(wpp_entry["Time Series"])
            else:
                # **Otherwise, add the entire WPP entry**
                lead_time_dicts[lead_time][unique_key] = wpp_entry

# Save merged data into separate files per lead time
output_dir = r"E:\MA_data\WPPs+production+reforecast"
os.makedirs(output_dir, exist_ok=True)

for lead_time, wpp_entries in lead_time_dicts.items():
    output_file = os.path.join(output_dir, f"WPPs+production+wind_lead_time_{lead_time}.json")
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(wpp_entries, f, indent=4)
    print(f"Saved merged file: {output_file}")

# %% [markdown]
# <h1>12. Plot normalised productions over wind speed to ensure plausibility (for some plants and lead times)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import json

# Define lead times of interest
lead_times = [0, 36, 72, 108, 144]

# Define input directory
input_dir = r"E:\MA_data\WPPs+production+reforecast"

# Initialize figure and axes
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15, 3), sharex=True)

# Loop through lead times and plot data
for idx, lead_time in enumerate(lead_times):
    input_file = os.path.join(input_dir, f"WPPs+production+wind_lead_time_{lead_time}.json")
    
    # Load JSON data
    with open(input_file, 'r') as file:
        data = json.load(file)
    
    wind_speeds = []
    normalised_powers = []

    # Extract wind speed and normalised power
    for plant in data.values():
        capacity = plant["Capacity"]
        for entry in plant["Time Series"]:
            wind_speeds.append(entry[2])  # Wind speed
            normalised_powers.append(entry[1] / capacity)  # Normalised power

    # Plot data
    axes[idx].scatter(wind_speeds, normalised_powers, c="blue", s=0.005)
    axes[idx].set_title(f"Lead Time: {lead_time} hours")
    axes[idx].set_ylabel("Normalised Power")
    axes[idx].set_xlabel("Wind Speed [m/s]")

# Adjust layout
plt.tight_layout()
plt.show()
